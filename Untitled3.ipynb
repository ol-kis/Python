# %%
import math
from sympy import*
from sympy.plotting import plot as plt
init_printing()

x = Symbol("x")
fx = -5*x**2 + 10*x - 30
fx
# Out:
#      2
# - 5⋅x  + 10⋅x - 30

# %%
p = plt(fx, (x,-7.5,7.5))

# %%
diff(fx)
# Out:
# 10 - 10⋅x

# %%
solve(fx)
# Out:
# [1 - √5⋅ⅈ, 1 + √5⋅ⅈ]

# %%
solve(diff(fx)>0)
# Out:
# -∞ < x ∧ x < 1

# %%
solve((fx>0))
# Out:
# False

# %% [markdown]
# solve((fx<0))
